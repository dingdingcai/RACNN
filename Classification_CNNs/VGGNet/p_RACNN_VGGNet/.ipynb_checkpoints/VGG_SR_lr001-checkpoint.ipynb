# %%
caffe_root = '/home/dingding/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)

import sys
import os
sys.path.insert(0, caffe_root + 'python')
import caffe
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
from IPython.display import clear_output
# %matplotlib notebook

caffe.set_device(0)
caffe.set_mode_gpu()

# %%
solver_file = '/home/dingding/ding3/stanford_cars/Nets/VGGNet/VGG_SR_lr001/VGGNet_solver_SR_lr001.prototxt'

weights = caffe_root + 'models/bvlc_vggnet/bvlc_vggnet.caffemodel'
weights1 = '/home/dingding/ding3/stanford_cars/Nets/SRCNN_prefix_int.caffemodel'
os.chdir(caffe_root)


solver = caffe.get_solver(solver_file)
solver.net.copy_from(weights)
solver.net.copy_from(weights1)
# solver.restore('/home/dingding/ding2/VDSR/stanford_cars/models/y_car_low_iter_425000.solverstate')

# %%
N = 15000000
disp_interval = 1000
loss = [0 for i in range(N)]
sum_loss = 0
mean_loss = list()
test_accuraries = list()
_, ax1 = plt.subplots()
plt.ion()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# test_accuraries = list()

for it in range(N):
    solver.step(1) 
    loss[it] = solver.net.blobs['loss'].data.copy()

    
    if it % disp_interval == 0 or it + 1 == N:
        print '%3d) loss = %s' % (it, loss[it])   
    
#     if it % 10000 == 0:
#         test_acc = solver.test_nets[1].blobs['accuracy'].data.copy()
#         test_accuraries.append(test_acc)
#         print 'test_acc = %s' % test_acc
        
    if it % 50000 == 0:    
        clear_output()
        
#         accumulate the average loss of every 50 iterations
    sum_loss = sum_loss + loss[it]
    if (it+1) % 50 == 0:
        mean_loss.append(sum_loss / 50.0)
        sum_loss = 0
    
#     every 5000th iteration, plot the loss curve figure
    if (it+1) % 10000 == 0:

        lines = ax1.plot(arange((it+1)/50), mean_loss,'r')
        ax1.set_xlabel('iteration') 
        ax1.set_ylabel('train_loss')
        ax1.set_title('Loss: {:.2f}'.format(mean_loss[-1]))
        try:
            plt.pause(0.1)
        except Exception:
            pass

        try:
            ax.lines.remove(lines[0])
            plt.show()
        except Exception as e:
            pass
# Out:
# 151000) loss = 1.82930040359
# 152000) loss = 1.66801714897
# 153000) loss = 1.43802297115
# 154000) loss = 1.65311038494
# 155000) loss = 2.55046606064
# 156000) loss = 0.766907334328
# 157000) loss = 1.18997192383
# 158000) loss = 0.951626181602
# 159000) loss = 1.27526521683
# 160000) loss = 1.45388150215
# 161000) loss = 1.55871498585
# 162000) loss = 1.02184319496
# 163000) loss = 1.36855828762
# 164000) loss = 1.32779479027
# 165000) loss = 1.42029547691
# 166000) loss = 1.96817839146
# 167000) loss = 1.72665786743
# 168000) loss = 1.75006043911
# 169000) loss = 1.08511257172
# 170000) loss = 1.07759952545
# 171000) loss = 1.77835392952
# 172000) loss = 1.16308927536
# 173000) loss = 1.32900607586
# 174000) loss = 1.58106040955
# 175000) loss = 1.45112943649
# 176000) loss = 0.823115944862
# 177000) loss = 0.993640899658
# 178000) loss = 1.94240522385
# 179000) loss = 2.39574313164

# %%
plt.savefig('/home/dingding/ding2/stanford_cars/Alex_srcnnx3.jpeg')

# %%
caffe_root = '/home/dingding/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)

import sys
import os
sys.path.insert(0, caffe_root + 'python')
import caffe
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
from IPython.display import clear_output
# %matplotlib inline

caffe.set_device(0)
caffe.set_mode_gpu()
solver_file = caffe_root + 'examples/FSRCNN/FSRCNN_solver.prototxt'

os.chdir(caffe_root)

solver = caffe.get_solver(solver_file)
# Out:
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \

# %%
#solvers = [('AlexNet', solver)]
solvers = [('FRSCNNNet', solver)]
N = 1000000
disp_interval = 100

blobs = ('loss') # the data(top) name of each layer

# blobs = ('loss', 'accuracy') 
loss = np.zeros(N)


sum_loss = 0
sum_acc = 0
mean_loss = list()
mean_acc = list()

_, ax1 = plt.subplots()
plt.ion()
plt.show()


for it in range(N):
    solver.step(1) 
    loss[it]= solver.net.blobs['loss'].data.copy()

    if it % disp_interval == 0 or it + 1 == N:
        loss_disp = 'loss = %.3f' % loss[it]
        print '%3d) %s \n' % (it, loss_disp)
                              
    if it % 5000 == 0:
        clear_output()
        
    sum_loss = sum_loss + loss[it]

    if (it+1) % 10 == 0:
        mean_loss.append(sum_loss / 10.0)
  
        sum_loss = 0

    
    if (it+1) % 1000 == 0:
        ax1.plot(arange((it+1)/10), mean_loss,'r')
        ax1.set_xlabel('iteration') 
        ax1.set_ylabel('train_loss')
        plt.pause(0.1)
# Out:
# 100) loss = 1.777
#
# 200) loss = 0.971
#
# 300) loss = 0.808
#
# 400) loss = 0.742
#
# 500) loss = 0.660
#
# 600) loss = 0.621
#
# 700) loss = 0.623
#
# 800) loss = 0.585
#
# 900) loss = 0.567
# /home/dingding/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.py:2437: MatplotlibDeprecationWarning: Using default event loop until function specific to this GUI is implemented
#   warnings.warn(str, mplDeprecation)
# 1000) loss = 0.545
#
# 1100) loss = 0.587
#
# 1200) loss = 0.520
#
# 1300) loss = 0.509
#
# 1400) loss = 0.515
#
# 1500) loss = 0.531
#
# 1600) loss = 0.445
#
# 1700) loss = 0.480
#
# 1800) loss = 0.489
#
# 1900) loss = 0.485
#
# 2000) loss = 0.464
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b4cfacc8e84c> in <module>()
#      21
#      22 for it in range(N):
# ---> 23     solver.step(1)
# ...

# %%
plt.savefig('/home/dingding/ding2/FSRCNN/loss_2.jpeg')

# %%
caffe_root = '/home/dingding/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)

import sys
import os
sys.path.insert(0, caffe_root + 'python')
import caffe
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
from IPython.display import clear_output
# %matplotlib inline

caffe.set_device(0)
caffe.set_mode_gpu()

os.chdir(caffe_root)

deploy = caffe_root + 'examples/FSRCNN/FSRCNN_deploy.prototxt'
weights = '/home/dingding/ding2/FSRCNN/caffemodels/FSRCNN_20_iter_2000.caffemodel'

net = caffe.Net(deploy, weights, caffe.TEST)
# Out:
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/dingding/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \

# %%
plt.rcParams['figure.figsize'] = (10, 10)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
print net.blobs['data'].data.shape
transformer.set_transpose('data', (2, 0, 1))
transformer.set_raw_scale('data', 255)
# transformer.set_channel_swap('data', (2, 1, 0))



img = caffe.io.load_image(caffe_root + 'examples/FSRCNN/Test/Set5/100.jpg', color=False)
print img.shape
# Out:
# (1, 1, 171, 171)
# (171, 171, 1)

# %%
transfered_img = transformer.preprocess('data', img)
plt.imshow(img[:,:,0])

# plt.show()
print transfered_img.shape


net.blobs['data'].data[...] = transfered_img

output = net.forward()
# Out:
# (1, 171, 171)

# %%
transfered_img
# Out:
# array([[[ 253.,  253.,  253., ...,  253.,  253.,  253.],
#         [ 252.,  252.,  252., ...,  253.,  253.,  253.],
#         [ 250.,  250.,  250., ...,  253.,  253.,  253.],
#         ...,
#         [ 112.,   99.,   95., ...,   50.,   59.,   66.],
#         [  84.,   74.,   75., ...,   50.,   59.,   66.],
#         [  68.,   62.,   66., ...,   50.,   59.,   66.]]], dtype=float32)

# %%
net_img = output['sum']
print net_img.shape
# HR_img = transformer.deprocess('data', net_img)
# plt.imshow(HR_img)
from scipy.io import savemat
savemat('/home/dingding/caffe/examples/FSRCNN/baby3.mat', {'bady':net_img[0,0,:]})
# Out:
# (1, 1, 513, 513)

# %%
net_img
# Out:
# array([[[[ 206.80984497,  264.05541992,  238.20231628, ...,  221.71980286,
#            249.62158203,  181.29730225],
#          [ 230.53567505,  272.8243103 ,  254.06390381, ...,  265.13043213,
#            252.84611511,  222.0511322 ],
#          [ 262.46636963,  249.72355652,  285.48626709, ...,  264.37719727,
#            266.10189819,  225.36735535],
#          ...,
#          [  73.88085938,   77.13883972,   81.07241821, ...,   72.67993164,
#             73.17286682,   67.10440063],
#          [  70.61654663,   78.21793365,   74.69728088, ...,   71.36192322,
#             70.80879974,   64.1940918 ],
#          [  62.54470062,   69.79201508,   72.32927704, ...,   64.35865021,
#             69.38110352,   66.39750671]]]], dtype=float32)

# %%
def vis_square(data):
    """Take an array of shape (n, height, width) or (n, height, width, 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""
    
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    # n x n
    padding = (((0, n ** 2 - data.shape[0]),
               (0, 1), (0, 1))                 # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    
    data = np.pad(data, padding, mode='constant', constant_values=1)  # pad with ones (white)
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
#     print data.shape
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
#     print data.shape
    plt.imshow(data); plt.axis('off')

# %%
filters = net.params['conv1'][0].data
print filters.shape
vis_square(filters.transpose(0, 2, 1))
# Out:
# (1, 1, 9, 9)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-4881d8500080> in <module>()
#       1 filters = net.params['conv1'][0].data
#       2 print filters.shape
# ----> 3 vis_square(filters.transpose(0, 2, 1))
#
# ValueError: axes don't match array

# %%
def plt_init(data):
    # setting figure size of inline display 
    # inches <==> pixels
    
    fig = plt.gcf()
    dpi = fig.get_dpi()
#     print dpi
    pixels = data.shape[2]
#     print pixels
    plt.rcParams['figure.figsize'] = (10, 10)        # large images
    plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
    plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
a = net.blobs['conv1'].data
print a.shape
# Out:
# (1, 1, 513, 513)

# %%
feat = net.blobs['sum'].data[0, :]
plt_init(feat)
print feat.shape
vis_square(feat)
# Out:
# (1, 513, 513)

# %%
feat = net.blobs['conv2'].data[0, :]
plt_init(feat)
print feat.shape
vis_square(feat)
# Out:
# (12, 171, 171)

# %%
net.blobs['conv3_2'].data[0, :]
# Out:
# array([[[  2.59545232e-07,   3.95697839e-08,   1.72911911e-07, ...,
#            1.69150979e-07,  -4.39414087e-08,   1.32708763e-07],
#         [ -3.55854866e-08,  -1.07894124e-07,   1.43071773e-07, ...,
#            8.54040678e-08,  -4.45670949e-08,   1.87514871e-07],
#         [  2.64704511e-07,  -1.08062558e-07,   4.04617595e-07, ...,
#            4.32887305e-07,  -1.22734516e-08,   3.14833471e-07],
#         ...,
#         [  1.05578394e-07,  -3.89239574e-08,   1.89527356e-07, ...,
#            1.33688957e-07,   4.75478643e-08,   1.27415660e-07],
#         [  7.90701620e-08,  -3.39008395e-08,   6.50648175e-08, ...,
#            1.32676305e-08,  -5.84647353e-09,   4.52415989e-08],
#         [  7.07447398e-08,  -1.02281907e-08,   1.04410326e-07, ...,
#            1.04044290e-07,   9.61334621e-08,   8.69209913e-08]],
#
#        [[ -8.70004939e-08,  -8.97856935e-08,  -1.13138995e-07, ...,
#           -3.88629431e-08,  -5.29481490e-08,   3.69479181e-07],
# ...

# %%
net.params['conv3_3'][0].data
# Out:
# array([[[[  6.59690937e-04,   1.61187339e-03,  -2.88330112e-03],
#          [  1.76403890e-04,   1.08045340e-03,  -5.01609748e-06],
#          [  1.08744200e-04,  -2.08021933e-03,   6.50642847e-04]],
#
#         [[ -2.94319238e-03,   9.53261158e-04,  -1.33868097e-03],
#          [ -6.06449503e-05,   7.59759278e-04,  -4.27594729e-04],
#          [ -7.65531149e-04,   3.36423633e-04,   1.59908470e-03]],
#
#         [[ -7.04587612e-04,  -1.31168072e-05,   1.20167574e-03],
#          [  1.56451517e-03,  -9.09849710e-04,  -1.05893036e-04],
#          [  1.16097706e-03,   1.15478423e-03,   1.29740321e-04]],
#
#         ...,
#         [[ -7.21925928e-04,  -6.00985833e-04,   1.53657061e-03],
#          [ -5.77219820e-04,   3.53661890e-04,  -4.55925125e-04],
#          [ -6.77267031e-04,   4.97594709e-04,  -2.79955973e-04]],
#
#         [[  8.87578062e-04,  -2.23452880e-04,  -1.18257776e-04],
#          [  1.55033672e-03,   1.24121085e-04,   4.48362043e-05],
# ...

# %%
# net_img = net.blobs['conv1_2'].data
net_img = net.blobs['conv5'].data

HR_img = transformer.deprocess('data', net_img)

# %%
print net_img.shape
print HR_img.shape
# Out:
# (1, 3, 513, 513)
# (513, 513, 3)

# %%
plt.imshow(HR_img)

plt.show()

# %%
lowx3 = [0.30,1.31,3.53,7.20,10.77,14.37,16.99,19.90,22.65,25.57,27.96,29.03,31.13,32.76,33.56,34.59]
